# %%
import osmnx as ox
import networkx as nx

# %%
G=ox.graph_from_bbox(35.7602,35.6439,139.6465,139.8158,network_type="drive")

# %%
hongo=(35.7114214, 139.7612027)
komaba=(35.6588839, 139.6833596)
komaba_pt=ox.distance.get_nearest_node(G,komaba)
hongo_pt=ox.distance.get_nearest_node(G,hongo)
komaba_pt,hongo_pt
# Out:
# /Users/kazuhiro/opt/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /Users/kazuhiro/opt/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# (366820243, 4506787861)

# %%
G_projected = ox.project_graph(G)
ox.plot_graph(G_projected,node_size=0)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
# Calculate the shortest path
route = nx.shortest_path(G=G_projected, source=hongo_pt, target=komaba_pt, weight='length')
# Show what we have
print(route)
fig, ax = ox.plot_graph_route(G_projected, route,node_size=0)
# Out:
# [4506787861, 792189822, 792189842, 1478183687, 1478183686, 792189840, 1478183659, 1483867281, 673425826, 2789738733, 673425825, 1067418378, 4506833597, 1436736511, 306452134, 1104760576, 1425858960, 2347366230, 1425858956, 1478206245, 664323351, 888744915, 3762107923, 3762107924, 1306915146, 727263512, 1306915074, 1784214188, 1784214156, 8035916868, 3790158127, 3790158109, 3790158143, 3790158119, 3790158116, 1566722347, 1566722650, 1573960946, 1679213318, 1822721262, 1808422619, 253889570, 1822721261, 1482464169, 475110184, 473169521, 197004459, 255366963, 255367232, 1808422548, 8738546592, 7294478075, 295395923, 4511333892, 473169504, 295396012, 1585577036, 295396092, 252673252, 295395896, 256203133, 256203137, 256203548, 1809615794, 158030830, 1254886050, 1254885972, 252833484, 2296577553, 1537676991, 252673597, 1537676903, 256203832, 955403167, 1715753257, 1071631271, 885679730, 885679738, 1111686866, 1312604285, 1312604284, 1312604282, 1312604290, 258035757, 1522593485, 256000221
# ...
